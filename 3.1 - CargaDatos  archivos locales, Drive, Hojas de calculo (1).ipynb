# %% [markdown]
# # Lectura de archivos
#
#
# Semana Tec
#
# Profesores: Luz Eunice Angeles /José Ignacio Treviño

# %% [markdown]
# Qué aprenderemos:
#
# - Subir archivos desde el sistema de archivos local
# - Descargar archivos en el slistema de archivos local
# - Acceder a google drive
#   - Activarlo de en el entorno de ejecución
#   - Usar una API : PyDrive
# - Crear y leer datos de google sheets

# %% [markdown]
# ## Subir archivos desde el sistema de archivos local
#
# <code>files.upload</code> es usado para cargar los archivos y conocer el diccionario de los archivos que se cargaron.
# El diccionario está codificado según el nombre de archivo y los valores son los datos que se subieron.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-3bb77efb-eaec-45ef-a444-2a43ec5d4ab5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3bb77efb-eaec-45ef-a444-2a43ec5d4ab5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving EjemploClase.csv to EjemploClase.csv
# User uploaded file "EjemploClase.csv" with length 37 bytes

# %% [markdown]
# ## Descargar archivos en el sistema de archivos local
#
# <code>files.download</code> invocará una descarga del archivo desde el navegador a tu computadora local.

# %%
from google.colab import files

with open('EjemploSemanaTec.txt', 'w') as f:
  f.write('Ejemplo de la clase de semana tec: analítica')

files.download('EjemploSemanaTec.txt')

# %%
ls
# Out:
# EjemploClase.csv  EjemploSemanaTec.txt  sample_data/

# %% [markdown]
# # Google Drive
#
# Puedes acceder a archivos en Drive de varias maneras, incluidas las siguientes:
# - Activación de Google Drive en la máquina virtual del entorno de ejecución
# - Usar un wrapper alrededor de la API, como <a href="https://gsuitedevs.github.io/PyDrive/docs/build/html/index.html">PyDrive</a>
# - Usar la <a href="https://developers.google.com/drive/v3/web/about-sdk">API nativa de REST</a>
#
#
#
# Puedes ver ejemplos de cada caso más abajo.

# %% [markdown]
# ## Activar Google Drive de forma local
#
# El ejemplo siguiente muestra cómo activar Google Drive en el entorno de ejecución mediante un código de autorización y cómo escribir y leer archivos allí. Una vez ejecutado, podrás ver el archivo nuevo &#40;<code>foo.txt</code>&#41; en <a href="https://drive.google.com/">https://drive.google.com/</a>.
#
# Ten en cuenta que solo se puede leer, escribir o mover archivos.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/SemanaTec/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat /content/drive/My\ Drive/SemanaTec/foo.txt
# Out:
# cat: '/content/drive/My Drive/semanaTec/foo.txt': No such file or directory

# %% [markdown]
# ## PyDrive
#
# En los ejemplos que aparecen a continuación, se muestran la autenticación y la carga y descarga de archivos mediante PyDrive. Puedes encontrar más ejemplos en la <a href="https://gsuitedevs.github.io/PyDrive/docs/build/html/index.html">documentación de PyDrive</a>.

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %% [markdown]
# Autentica y crea el cliente de PyDrive.

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# Lista de ids de cada carpeta que tenemos en el google drive

# %%
file_list = drive.ListFile({'q': "'root' in parents and trashed=false"}).GetList()
for file1 in file_list:       
    print ('title: %s, id: %s' % (file1['title'], file1['id']))
# Out:
# title: SemanaTec, id: 1OrNu1-PnuqydOccf1Dpwb4C3qRIxCPbw
# title: MACxWINDOWS, id: 1-PjDX0e8FBIdLTQ4oxIfJ-KqkcfzfKcyelTxikl7ZVw
# title: Case 1 Quiz, id: 1mJxYcFc5FayF3Dt5xzQFUV6BcYs1DLXrsKO-TH1Hlv4
# title: Actividad 2.1 Practicando los lenguajes regulares, id: 1t6YiFKm27gRNmcNW7w25D0ax5ARMcaPSSx9CyzrqwqQ
# title: Captura de Pantalla 2021-03-11 a la(s) 10.21.54 p.m..png, id: 1gfvbjHZ3ginjl-c-tKpGDduVHtkJLrhx
# title: Acordeon Bases de Datos, id: 1rSYVWmWrnv5Z75A1oBe-BhO16TnOlQz11Cu080dtUd0
# title: 2.3.3 - Mapeo Movie, id: 1pW5275QwKjXPMlSaw9wCSdvhnH8g5TePCQVTOp7Ca6k
# title: 2.3.2 - Mapeo Vote, id: 1Zgu0uzuWl3ZMJpUT5pFoO_EKZLBpZjA0YjK2Ou3k7ew
# title: 2.3.1 - Mapeo Music/Horse, id: 1SIR2ouKeh2gcg_ONM5YU3hZuFQfLTFCwK1uefBRGVms
# title: Mapeo genérico, id: 1jt3DX8EcjSTiyHaUsWai8TwOucviZ6CWyE5KWkCwHBE
# title: Act 2.2 - Verificación de las funcionalidades de una estructura de datos lineal, id: 1qCvEVpT_M_to6XRW5NedXzCRhlGlWSfnXhjKL_VqRqs
# title: Mapeo Modelo Entidad-Relación Music, id: 1KqgcqMWQO3mhQFmLuwUPIWgYLmxturoqI0j0gvgZOho
# title: Tarea 2: Sistemas numéricos y punto flotante, id: 1xt8Lu6UwScbemAaPV9KzS5wD8SqrhmHmsaSN9uM5lj4
# title: 2.2.1 - Actividad ER - Apps, id: 1BIXi48uKrwsBZG5bQ3HtdJYOFqLPPZ83Lan5pUKVnf0
# title:  Puntos Extra Leonard Kleinrock, id: 1wOtUQFdfmId3Uieh14eDGjU49szmyT_20b3Px3sUPnA
# title: Tarea individual | Macromoléculas, id: 1VY1eGvrobyGJD3RFL6yRuLB3FD8Dq-tRDdVr_Ee3zME
# title: Actividad en clase | Analogía computadora y la célula, id: 1UyxVr6A2HAT0lAaPh0kXXlKyIcltqaPpDxkFDPwRZ18
# title: Avance 1 de situación problema, id: 1DX3b4gUSTlCWSO_vR5Hspg_H5MYmpcZapMP_l6mdN2o
# title: ¿Qué sigue en base de datos?, id: 1q7bp5BZrc7G_eAKpWhbq-yw3uAUY6EoZqYZAodW4tFQ
# title: Tarea 1: Ensayo sobre evolución de las computadoras y el desarrollo humano, id: 1zOa9x9iCmW1be3W1_On8ZmOo5lmGFKWriTXLaNtWqcI
# title: 2.1.1. Instalación de MySQL, id: 146otYO9OqwIES54E7FFh7XLBqE96W3wCfrGsrGbj5Io
# title: Workshop 7, id: 1Hi_vPL_jTDBiuKst3IQDWiEzbNGjKnyfUTn-iStbs7k
# title: Copia de Actividad-Restricciones, id: 15gpLLMYCWomfuDzUC4t8WF-M7mMQoiX7epOtEsYlDpQ
# title: Subsistema info.docx, id: 1RoE63PSo8rECQc1Ns4-ZQaFsLdj0bWZ4
# title: Actividad 3. Infografía: Erradicar la intolerancia, id: 1aYULGUW-B_lErpYBPN6iU7GmdEeeSZ0zE85eZtLasRo
# title: ReflexAct1.3, id: 1XxNguULZgjApUkZSCLy1db24rOfs1m75ryV_FlzdR5s
# title: Actividad 1. Video journal - Role models femeninos y masculinos, id: 1V6dJrkE1ta2G41n0txOesrhow5yf7Qcaixkdh3eu4K8
# title: Evidencia 2: Bitácora, id: 1RgY1L_KUSC9g2EctRITDkw6IZNs6L1N72nmsZMouuGE
# title: Actividad Integradora por equipos, id: 1FmEImQZjNDc0LCMfp-aRGTufOl3SYMI_7GdKa84iyIA
# title: PF_09SeptiembreED, id: 1qT5MZzbmIkRuTcHIX-llnkuhXwzSe61e5rzaiH0v3yA
# title: Evaluación de precisión, id: 1FujiothoHXMP1Qeffk0DEgjVrZSMZRJHrnMheTGgG9I
# title: Tabla algoritmos de ordenamiento, id: 1rbgjyItIy5P7JQBbeMrg1WAi6W7rGlgNCka1Iy0zsBM
# title: Presentación patentes, id: 1MMbDsucfMNBcL6o7k5y2UxLye6SZhDYJdnNgLsS-w8w
# title: Actividad 1.2.b Problema Parcial de Distribución, id: 1AKAJoGKkQs2N7itvYCvguI38fexbXJtplyJ2w3pobM4
# title: Análisis introductorio de los elementos de una patente, id: 12iXqgqZtmNxVSE8F5fU7yoE6wnwN0SkfWR8TpNDDTCA
# title: Figura1Distribución.jpg, id: 1ovNewFxY03Irjl_AdGH4HQHC13a3DlRn
# title: EA1_3Septiembre_A01280603, id: 10IEDMt5zB2FiHfwLTaF4Pek9b1zxDriUkVbNVdy0xEc
# title: Ecuaciones lineales no homogéneas con coeficientes constantes . Variación de parámetros, id: 121kgrJOyvnURxfkG_Xgxe99shrO2jfty443pjD0oEiU
# title: Ecuaciones lineales no homogéneas con coeficientes constantes. Coeficientes indeterminados, id: 1viM3z1vFYX2R8Usk05C2ZlW6QPJFgKWja9tcb07fwok
# title: Ecuaciones lineales homogéneas con coeficientes constantes, id: 1w8J-NuHxwd1-rRQ31GO-woqfS7SO6xEpQvejdbpJVsE
# title: Ecuaciones Lineales y Bernoulli, id: 13JjrzbmOed5WYHmkIQPHcJAk90wGtcuYOscO_XkswGE
# title: Workshop 2 , id: 1C3aSxxtgKQWCNxFk0zVzz-qlKRwpGcAkr6cmyOkWMYo
# title: Ecuaciones Exactas y Factor Integrante, id: 13AgxB117OFjlKEtgP2URjkxmQtKfAf0cPS-IoBfC4ac
# title: Ecuaciones de variables separables y homogéneas, id: 1f2QCiX6rbDIbl_Io87v-2MeqKnnDGMndBdFeQk_geSs
# title: Workshop, id: 1VwxMk0Sqe0YJe-S-amLd1DIPnH7syE1FufYUNpnwuvg
# title: Evidencia: Proyecto Integrador, id: 1zmXTpdK3-PdjcoOOXs81p7p9PQY4E2xu4WtAjY0ZQC0
# title: Actividad de reflexión ¿Con qué me quedo?, id: 1JSnABQIDcQMpMN1AlBokEWRyPDYouU4xTYJji9KyVdI
# title: Actividad Mi historia este semestre (presentación), id: 1F_HVdBY7uaPC0deRNnpUk_d5JJ7Up4UuBhgWGeOQa8g
# title: Actividad de modelos de pronósticos (Situación Problema 2), id: 1tGX_VE_VP4Bxo6At1HxTnFBbOGhhsNN-9CXLUre1NhE
# title: RETO FINAL, id: 19E_CIsZIC8x8vW9wIofKFzKwbz02OGYyFYwvhV3jdxU
# title: Situación Problema Modelación Matricial , id: 1xlx4PuY4jDC0Wk4Uo3ykhO4t1H_vTNvizwRxGk94qbY
# title: A2M2. Actividad Inductancia, id: 1Gpp0M0xr8F_TmE9eoKgSCFzDwvPs0ZnC7Q6QTHxfU8k
# title: A2M2. Actividad Inductancia.pdf, id: 1HCMm6YiZ73cSEmUmDmTrpx8cAgp8-8o3
# title: Edipo Rey Párrafo, id: 1-gYWrl4OrCcCc11QiGNmw86V6ZB3XUfK_51Ev-B-qYQ
# title: Proyecto Final Bio, id: 1-btgUV8DYJwP6PihnqHanzfNLr6jNCH4Re0oIpXXVhk
# title: Port-CEGL-A01280603, id: 0B0BfDhME9S9RbXNaRzZ1RDNQeGM
# title: AUTOEVALUATION, id: 1-3sdj9XQRExXcWPY-D13zHxQH95s2OLML-5vcY6KuVQ
# title: creativity design 403, id: 0B0BfDhME9S9RbTFhMDJBRFlhaWM

# %%
fid= '1OrNu1-PnuqydOccf1Dpwb4C3qRIxCPbw'

# %% [markdown]
# Crea y sube un archivo de texto.

# %%
uploaded = drive.CreateFile({'title': 'EjemploSemanaTec01.txt','parents':[{"id":fid}]})
uploaded.SetContentString('Sample upload file content')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1VrHn2tFH9vGyBHjrH0CP1zjfKkD1_94c

# %% [markdown]
# Carga un archivo por su ID y luego imprime su contenido.

# %%
uploaded.get('id')
# Out:
# '1VrHn2tFH9vGyBHjrH0CP1zjfKkD1_94c'

# %%
downloaded = drive.CreateFile({'id': uploaded.get('id')})
print('Downloaded content "{}"'.format(downloaded.GetContentString()))
# Out:
# Downloaded content "Sample upload file content"

# %% [markdown]
# # Hojas de cálculo de Google
#
# Los ejemplos de abajo usan la biblioteca de código abierto <a href="https://github.com/burnash/gspread"><code>gspread</code></a> para interactuar con Hojas de cálculo de Google.
#
# Primero, instala el paquete usando <code>pip</code>.

# %%
# !pip install --upgrade --quiet gspread

# %% [markdown]
# Importa la biblioteca, autentica y crea la interfaz para Hojas de cálculo.

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

# %% [markdown]
# A continuación, verás un pequeño conjunto de ejemplos de <code>gspread</code>. Puedes encontrar más ejemplos en la <a href="https://github.com/burnash/gspread#more-examples">página de GitHub de <code>gspread</code></a>.

# %% [markdown]
# ## Crear una hoja nueva con datos de Python

# %%
sh = gc.create('EjemploSpreadSheetST')

# %% [markdown]
# Después de ejecutar la celda anterior, se mostrará una nueva hoja de cálculo con el nombre "My cool spreadsheet" en <a href="https://sheets.google.com/">https://sheets.google.com</a>.
#
# Abre la hoja nueva y agrega datos aleatorios.

# %%
worksheet = gc.open('EjemploSpreadSheetST').sheet1

cell_list = worksheet.range('A1:C2')

import random
for cell in cell_list:
  cell.value = random.randint(1, 10)

worksheet.update_cells(cell_list)
# Out:
# {'spreadsheetId': '1beyDyP7vq9cdz7X6d3wo44N6Vs9q8Or5qLxc6nsZDj4',
#  'updatedCells': 6,
#  'updatedColumns': 3,
#  'updatedRange': "'Hoja 1'!A1:C2",
#  'updatedRows': 2}

# %% [markdown]
# ## Descargar datos de una hoja de cálculo en Python como un DataFrame de Pandas
#
# Vuelve a leer los datos aleatorios que insertamos anteriormente y convierte el resultado en un <a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html">DataFrame de Pandas</a>.

# %%
worksheet = gc.open('EjemploSpreadSheetST').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print('******************Lista de datos*********************')
print(rows)

import pandas as pd
dataset=pd.DataFrame.from_records(rows)
print('******************Data Frame*********************')
print(dataset)
# Out:
# ******************Lista de datos*********************
# [['2', '2', '7'], ['7', '7', '6']]
# ******************Data Frame*********************
#    0  1  2
# 0  2  2  7
# 1  7  7  6
